# %%
import numpy as np  
import pandas as pd  
from pandas_datareader import data as web  
import matplotlib.pyplot as plt  
from scipy.stats import norm
import datetime
# %matplotlib inline

# %%
start = datetime.datetime(2017,1,1)
end = datetime.dow()
data = wb.DataReader("AMZN","morningstar",start,end)
ticker = 'AMZN' 
data = pd.DataFrame()
data[ticker] = wb.DataReader(ticker, data_source='morningstar',end)['Close']
data[ticker]

# %%
start = datetime.datetime(2018, 1, 1)
end = datetime.datetime.now()
data = web.DataReader("AMZN", 'morningstar', start, end)
data.reset_index(inplace=True)
data.set_index("Date", inplace=True)
data = data.drop("Symbol", axis=1)
pandaclose = pd.DataFrame(data['Close'])
pandaclose
# Out:
#               Close
# Date
# 2018-01-01  1169.47
# 2018-01-02  1189.01
# 2018-01-03  1204.20
# 2018-01-04  1209.59
# 2018-01-05  1229.14
# 2018-01-08  1246.87
# 2018-01-09  1252.70
# 2018-01-10  1254.33
# 2018-01-11  1276.68
# 2018-01-12  1305.20
# 2018-01-15  1305.20
# 2018-01-16  1304.86
# 2018-01-17  1295.00
# 2018-01-18  1293.32
# 2018-01-19  1294.58
# 2018-01-22  1327.31
# 2018-01-23  1362.54
# 2018-01-24  1357.51
# 2018-01-25  1377.95
# 2018-01-26  1402.05
# 2018-01-29  1417.68
# 2018-01-30  1437.82
# 2018-01-31  1450.89
# 2018-02-01  1390.00
# 2018-02-02  1429.95
# 2018-02-05  1390.00
# 2018-02-06  1442.84
# 2018-02-07  1416.78
# 2018-02-08  1350.50
# 2018-02-09  1339.60
# ...             ...
# 2018-05-28  1610.15
# 2018-05-29  1612.87
# 2018-05-30  1624.89
# 2018-05-31  1629.62
# 2018-06-01  1641.54
# 2018-06-04  1665.27
# 2018-06-05  1696.35
# 2018-06-06  1695.75
# 2018-06-07  1689.30
# 2018-06-08  1683.99
# 2018-06-11  1689.12
# 2018-06-12  1698.75
# 2018-06-13  1704.86
# 2018-06-14  1723.86
# 2018-06-15  1715.97
# 2018-06-18  1723.79
# 2018-06-19  1734.78
# 2018-06-20  1750.08
# 2018-06-21  1730.22
# 2018-06-22  1715.67
# 2018-06-25  1663.15
# 2018-06-26  1691.09
# 2018-06-27  1660.51
# 2018-06-28  1701.45
# 2018-06-29  1699.80
# 2018-07-02  1713.78
# 2018-07-03  1693.96
# 2018-07-04  1693.96
# 2018-07-05  1699.73
# 2018-07-06  1710.63
#
# [135 rows x 1 columns]

# %%
log_returns = np.log(1 + pandaclose.pct_change())
log_returns.tail()
# Out:
#                Close
# Date
# 2018-07-02  0.008191
# 2018-07-03 -0.011632
# 2018-07-04  0.000000
# 2018-07-05  0.003400
# 2018-07-06  0.006392

# %%
pandaclose.plot(figsize=(10, 6));

# %%
log_returns.plot(figsize = (10, 6))

# %%
u = log_returns.mean()
u
# Out:
# Close    0.002838
# dtype: float64

# %%
var = log_returns.var()
var
# Out:
# Close    0.000303
# dtype: float64

# %%
drift = u - (0.5 * var)
drift
# Out:
# Close    0.002687
# dtype: float64

# %%
stdev = log_returns.std()
stdev
# Out:
# Close    0.017401
# dtype: float64

# %%
type(drift)
# Out:
# pandas.core.series.Series

# %%
type(stdev)
# Out:
# pandas.core.series.Series

# %%
np.array(drift)
# Out:
# array([ 0.00268675])

# %%
drift.values
# Out:
# array([ 0.00268675])

# %%
stdev.values
# Out:
# array([ 0.01740068])

# %%
norm.ppf(0.999)
# Out:
# 3.0902323061678132

# %%
x = np.random.rand(10, 2)
x
# Out:
# array([[ 0.1049839 ,  0.81320621],
#        [ 0.58790592,  0.83002885],
#        [ 0.13777808,  0.3504686 ],
#        [ 0.14695026,  0.54294239],
#        [ 0.36016114,  0.01683885],
#        [ 0.15595486,  0.04244455],
#        [ 0.19513819,  0.30450125],
#        [ 0.7230824 ,  0.77509978],
#        [ 0.64048505,  0.97272931],
#        [ 0.91555098,  0.24154233]])

# %%
norm.ppf(x)
# Out:
# array([[-1.25365397,  0.88977338],
#        [ 0.2221615 ,  0.95427926],
#        [-1.09035643, -0.38405565],
#        [-1.04960335,  0.10784933],
#        [-0.35802812, -2.12390972],
#        [-1.01122298, -1.72299682],
#        [-0.85911625, -0.51149785],
#        [ 0.59202299,  0.75574776],
#        [ 0.3597556 ,  1.92251186],
#        [ 1.37575322, -0.70134994]])

# %%
Z = norm.ppf(np.random.rand(10,2))
Z
# Out:
# array([[-0.09407712,  0.27753532],
#        [-0.67991544,  0.10633551],
#        [ 0.92893224, -0.09177613],
#        [-0.63434033, -0.20225078],
#        [-0.76692848,  0.13904814],
#        [-0.49983524, -1.8016851 ],
#        [ 1.59736251, -0.81253229],
#        [ 0.09241889, -0.68561101],
#        [-1.37950134, -0.30885595],
#        [ 0.86714265, -0.17729336]])

# %%
t_intervals = 360
iterations = 3

# %%
daily_returns = np.exp(drift.values + stdev.values * norm.ppf(np.random.rand(t_intervals, iterations)))

# %%
S0 = pandaclose.iloc[-1]
S0
# Out:
# Close    1710.63
# Name: 2018-07-06 00:00:00, dtype: float64

# %%
price_list = np.zeros_like(daily_returns)

# %%
price_list[0] = S0

# %%
for t in range(1, t_intervals):
    price_list[t] = price_list[t - 1] * daily_returns[t]

# %%
price_list
# Out:
# array([[ 1710.63      ,  1710.63      ,  1710.63      ],
#        [ 1717.03590457,  1679.00891997,  1701.6148884 ],
#        [ 1657.86046624,  1638.09918504,  1703.25707027],
#        ...,
#        [ 3404.16307341,  3867.31416874,  3274.16904874],
#        [ 3385.48861874,  3813.27454134,  3150.02347514],
#        [ 3401.18101397,  3880.13018272,  3131.86002444]])

# %%
price_list[:,0]

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(price_list);

# %%
dnp=np.array(pandaclose)

# %%
len(dnp)
# Out:
# 135

# %%
t=np.linspace(-134,0,135)

# %%
fig = plt.figure()

ax = fig.add_subplot(1, 1, 1)
plt.xlim(-50,150)
plt.ylim(1400,3000)


ax.plot(price_list);

ax.plot(t,dnp, color  = "k");

# %%
trecta=np.linspace(0,90,100)
def recta(t):
    return 9.1667*t + 1725
def recta_inf(t):
    return -3.1667*t + 1725

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.xlim(-50,150)
plt.ylim(1400,3000)
ax.plot(price_list);
ax.plot(t,dnp, color  = "k");
ax.plot(trecta,recta(trecta), color  = "r");
ax.plot(trecta,recta_inf(trecta), color  = "r");

# %%
g=recta(trecta)
g
# Out:
# array([ 1725.        ,  1733.33336364,  1741.66672727,  1750.00009091,
#         1758.33345455,  1766.66681818,  1775.00018182,  1783.33354545,
#         1791.66690909,  1800.00027273,  1808.33363636,  1816.667     ,
#         1825.00036364,  1833.33372727,  1841.66709091,  1850.00045455,
#         1858.33381818,  1866.66718182,  1875.00054545,  1883.33390909,
#         1891.66727273,  1900.00063636,  1908.334     ,  1916.66736364,
#         1925.00072727,  1933.33409091,  1941.66745455,  1950.00081818,
#         1958.33418182,  1966.66754545,  1975.00090909,  1983.33427273,
#         1991.66763636,  2000.001     ,  2008.33436364,  2016.66772727,
#         2025.00109091,  2033.33445455,  2041.66781818,  2050.00118182,
#         2058.33454545,  2066.66790909,  2075.00127273,  2083.33463636,
#         2091.668     ,  2100.00136364,  2108.33472727,  2116.66809091,
#         2125.00145455,  2133.33481818,  2141.66818182,  2150.00154545,
#         2158.33490909,  2166.66827273,  2175.00163636,  2183.335     ,
#         2191.66836364,  2200.00172727,  2208.33509091,  2216.66845455,
#         2225.00181818,  2233.33518182,  2241.66854545,  2250.00190909,
#         2258.33527273,  2266.66863636,  2275.002     ,  2283.33536364,
#         2291.66872727,  2300.00209091,  2308.33545455,  2316.66881818,
#         2325.00218182,  2333.33554545,  2341.66890909,  2350.00227273,
#         2358.33563636,  2366.669     ,  2375.00236364,  2383.33572727,
#         2391.66909091,  2400.00245455,  2408.33581818,  2416.66918182,
#         2425.00254545,  2433.33590909,  2441.66927273,  2450.00263636,
#         2458.336     ,  2466.66936364,  2475.00272727,  2483.33609091,
#         2491.66945455,  2500.00281818,  2508.33618182,  2516.66954545,
#         2525.00290909,  2533.33627273,  2541.66963636,  2550.003     ])

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.xlim(-50,150)
plt.ylim(1400,3000)
ax.plot(price_list);
ax.plot(t,dnp, color  = "k");
ax.plot(trecta,recta(trecta), color  = "r");
ax.plot(trecta,recta_inf(trecta), color  = "r");

# %%
def yinf(x,y,n,xini,xfin,yini,yfin):
    j=0
    count=0
    for i in range(n):
        if (y[i]>yini>y[j]) or (y[i]<yini<y[j]):
                if xini <x[j]<xfin:
                    count += 1
        j = i
    return count

# %%
yinf(t,price_list[:,0],150,0,90,1725,1400)
# Out:
# 0
