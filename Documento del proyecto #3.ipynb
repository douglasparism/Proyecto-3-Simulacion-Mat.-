# %% [markdown]
# ##  <font color= "grey">Materia :</font> <font color = "blue"> Simulacion Matematica </font>
# ## <font color= "grey">Proyecto :</font> "Montecarlo en las finanzas"

# %% [markdown]
# ##  <font color= "blue"> 1.2 Objetivos </font>

# %% [markdown]
# ### **              El objetivo general del proyecto es utilizar Montecarlo y otros metodos aprendidos en clase pars poder ver posbiles situaciones futuras, para aplicar en las finanzas con el precio de las acciones y opciones en un periodo de tiempo. **

# %% [markdown]
# ### <font color= "red">Objetivos especificos</font>

# %% [markdown]
#     · El trabajo tiene como objetivo el usar las herramientas aprendidas durante la tercera parte del curso de simulacion matematica
#
#       · Importar y manipular bases de datos a traves de la libreria Pandas.
#
#       · El uso de funciones para simular posibles situaciones, como Montecarlo.
#
#       · Graficar los posbibles escenarios.

# %% [markdown]
# **Los componentes del trabajo son **
# 1. Importar bibliotecas.
# 2. Importar informacion de valores y acciones de la pagina "Morningstar.
# 3. Crear dataframes, para manipular los datos.
# 4. Definir periodo de tiempo.
# 5. Utilizar la función de volatilidad.
# 6. Graficar la volatilidad de la accion.
# 7. Utilizar numeros aleatorios para poder ver como se comporta el modelo.

# %% [markdown]
# ## <font color = "blue"> 1.3 Modelo </font>

# %% [markdown]
# ### Condiciones y Restricciones

# %% [markdown]
# - Las condiciones iniciales son importadas del portal <font color = "red"> "Morning Star" </font> según el periodo de tiempo que se estipule.
# - La importación contiene la fecha y el precio de la acción en la misma, como indica el formato de abajo...
# - En la última parte del trabajo se utilizan números pseudo-aleatorios para las pruebas.

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Situación

# %% [markdown]
# ** <font color = "grey"> En las finanzas hay bastantes fluctuaciones de cotizaciones o precios de acciones, lo cual genera mucha incertidumbre en el mundo corporativo, nuestro modelo a traves de Montecarlo buscara los precios más probables viendo la volatilidad que tuvo esa accion en cierto periodo de tiempo. </font> **

# %% [markdown]
# ### Ecuaciones

# %% [markdown]
# Las ecuaciones son:
#
#   $V = \ln 1+{\frac {p_{i}}{p_{i-1}}}$
#
#   $D = u - (.5 \times v )$
#
#   $G = \exp ^{D.valores + DS.valores * N}$
#
# Donde:
#
#   $V$ = Volatilidad de la acción
#
#   $p_{i}$: Precio de la acción.
#
#   $p_{i-1}$: Precio anterior de la acción
#
#   $D$ : Drift
#
#   $N$  : Normal y continua variable aleatoria
#
#   $u$ : Promedio de Volatilidad
#
#   $DS$ : Desviación Estandar de Volatilidad
#
#   $v$ : Varianza de Volatilidad
#
#   $G$  : Ganancia diaria

# %% [markdown]
# ## <font color = "blue"> 1.5 Visualización </font>

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ** Información sobre la volatilidad **

# %%
pic = mpimg.imread("Datos de volatilidad.jpg")
plt.imshow(pic)
plt.axis("off")
plt.show()

# %% [markdown]
# ** Grafica de Volatilidad**

# %%
imagen = mpimg.imread("Volatilidad.jpg")
plt.imshow(imagen)
plt.axis("off");

# %% [markdown]
# ** Grafica con Montecarlo **

# %%
Montecarlo = mpimg.imread("Montecarlo.jpg")
plt.imshow(Montecarlo)
plt.axis("off");

# %% [markdown]
# ** Margen **

# %%
Margen = mpimg.imread("Margen.jpg")
plt.imshow(Margen)
plt.axis("off");

# %% [markdown]
# ** Margen Con Alphas **

# %%
Margen = mpimg.imread("Margenalpha.jpg")
plt.imshow(Margen)
plt.axis("off");

# %% [markdown]
# ##  <font color = "blue" > 1.6 Conclusiones  </font>

# %% [markdown]
# *Las finanzas son muy impredecibles ya que se toman en cuenta demasiadas variables para el precio de una acción o valor, varias de las variables no son posibles de identificar y es por eso la dificultad de encontrar un modelo que sirva en la vida real. Nosotros buscabamos a tráves de calculos matematicos sobre la volatilidad y precios historicos con el fin de hallar posibles escenarios para así poder ver cual es la mayor posiblilidad.*
#
# *Las funciones que se utilizaron no fueron complicadas y algunas hasta ya estaban definidas en las librerias que importamos, aunque si tuvimos que investigar mas de probabilidad y estadistica para conseguir numeros que aunque fueran aleatorios se encontraran dentro del rango de posibilidades. Se pudo cumplir el objetivo del proyecto ya que se buscaba la simulación de posibles escenarios del futuro con las herramientas y aprendizajes aprendidas en clase como Montecarlo , sin embargo no hay tanta exactitud como para poder usar el modelo en las finanzas bursatiles.*
#
# *La mayoria del mercado se mueve por lo que va a valer una acción, y aunque parametros del pasado son importantes, influye más la confianza en esa empresa y la tendencia hacia la que tiende a ir los negocios, las empresas y la economía, cosas que no podemos medir con los conocimientos actuales que tenemos. La información es lo unico que te puede dar ventaja en la bolsa de valores, si solo si tu eres la unica persona que lo sabes.*

# %% [markdown]
# ## 1.7 Bibliografia

# %% [markdown]
# - https://www.morningstar.com/stocks/xnas/amzn/quote.html
# - https://www.investopedia.com/articles/investing/112514/monte-carlo-simulation-basics.asp
# - http://www.pythonforfinance.net/2016/11/28/monte-carlo-simulation-in-python/
# - http://programmingforfinance.com/2017/11/monte-carlo-simulations-of-future-stock-prices-in-python/
